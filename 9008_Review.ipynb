# %% [markdown]
# <a href="https://colab.research.google.com/github/SunmoonTao/colab/blob/master/9008_Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> Welcome back! </h1>
#
# Hello everyone, hope you all had a wonderful winter break and that it was filled with quality family and personal time! Before we get started, let us know what cool things you did (or received) over the break! This can be as long or as short as you want.
#
# Please remember to save a copy of this notebook (and future notebooks) in your drive and not to directly edit this notebook.

# %% [markdown]
# [Edit this text box to let us know what interesting things you did!]

# %% [markdown]
# <h2> Let's review! </h2>
#
# Coming back to coding after not using it for a while might be challenging. To help you get back into the rhythm of things, this notebook will review material from 9005 to 9007.
#
# There will be three tasks this notebook:
#
# 1.   Complete the Review Notebooks that covers 9005 and 9006
# 2.   Practice with Decision Tree and Random Forest Exercises
# 3.   Create a concept map of machine-learning

# %% [markdown]
# <h3> Task 1: Complete the Review Notebooks that covers 9005 and 9006 </h3>
#
# To refresh your basics, complete these two notebooks that cover material from 9005 and 9006.
#
# 9005 Review:
#
# [Matt's notebook](https://colab.research.google.com/drive/19ADIgzJpVdlXGvMgXYdpj27ffZ3uwYKE?usp=sharing) on using functions and creating your own functions as well as importing libraries and using functions of those libraries
#
# 9006 Review:
#
# [Jennifer's notebook](https://colab.research.google.com/drive/175HxuWHzA9TQaqKlbxBDlN8UA75Gkt1v?usp=sharing) on object-oriented programming (OOP) and how to apply it to the Gene Finding Project from 9005

# %% [markdown]
# <h3> Task 2: Decision Tree and Random Forest Review </h3>
#
# In 9007, we learned a lot about machine-learning and, similar to how we've completed notebooks in 9007, we're going to complete a simple Decision Tree and Random Forest model to predict whether a patient will have [Kyphosis](https://www.google.com/search?q=define+kyphosis&rlz=1C1CHBF_enUS819US819&oq=define+kypho&gs_lcrp=EgZjaHJvbWUqBwgAEAAYgAQyBwgAEAAYgAQyBwgBEAAYgAQyBggCEEUYOTIHCAMQABiABDIHCAQQABiABDIHCAUQABiABDIHCAYQABiABDIHCAcQABiABDIICAgQABgWGB4yCAgJEAAYFhgeqAIAsAIA&sourceid=chrome&ie=UTF-8) or not after corrective surgery.
#
# Make sure to have downloaded the 'kyphosis.csv' file from Canvas before starting!

# %% [markdown]
# Here are the steps we need to take in order to implement DT and RF:
#
# 1.   Import the proper libraries, load the dataset, and take a look at the dataset
#
# 2.   Split the dataset into a training and testing set for the model and use it with the model
#
# 1.   Evaluate the model

# %% [markdown]
# <h4> Step 1: Preparation </h4>
#
#
# You need to import the following libraries:
#
#
# *   Pandas (pd)
# *   Numpy (np)
#
# *   from sklearn.model_selection (train_test_split)
# *   from sklearn.tree (DecisionTreeClassifier)
#
# *   from sklearn.ensemble (RandomForestClassifier)
#
# *   from sklearn (metrics)
# *   from sklearn.metrics (confusion_matrix)
#
# Then use pandas to load the dataset and take a look at the dataset.

# %%
# import your libraries here

# load in the dataset as a dataframe

# look at the first 10 entries of the dataframe

# %% [markdown]
# To break it down a little bit:
#
#
# *   Age of patient in months
#
# *   Number of vertebrae afected
#
# *   Start -ing at which vertebrae (there are 33 vertebrae in the spine)

# %% [markdown]
# <h4> Step 2: Training the Model </h4>
#
# Recall that we have to split the dataset into a training and testing dataset.
#
# In this exercise, we're trying to predict whether or not a patient will have Kyphosis present or absent after having corrective surgery. This means we'll have to drop the Kyphosis column but store it as our 'answer key'.

# %%
# drop the Kyphosis column and store the new dataframe as a variable X
# use (axis = 1) as a parameter to ensure that you drop the columns and not rows

# store the Kyphosis column as y

# create your training and testing sets with X and y

# %% [markdown]
# We're now ready to train the model!
# If you need a refresher, revisit your Module 2a Notebook (specifically step 6).

# %%
# create the Decision Tree Classifier object

# train your decision tree with the proper X and y values (and update your Decision Tree Classifier variable!)

# %% [markdown]
# With the model trained, let's do some predictions!

# %%
# use X_test to make predictions and save it as a variable

# %% [markdown]
# <h4> Step 3: Evaluate your model </h4>
#
# Now that your model made some predictions, see how it did!

# %%
# print a confusion matrix using y_test and the predictions variable you made

# print out the accuracy of your model as one value

# %% [markdown]
# Write here about:
#
#
# *   What accuracy did you get?
# *   What kind of predictions did your Decision Tree make? For example, "My model incorrectly predicted Kyphosis was present in 3 patients when Kyphosis was actually absent."
#
# *   What are some ways that you can do some hyperparameter tuning in order to increase accuracy?

# %% [markdown]
# <h4> Let's run it back one more time for Random Forest </h4>
#
# The way you would train a Random Forest classifier is not too different from the Decision Tree classifier!
#
# If you need a refresher, revisit your Module 3a Notebook (under "Training the model using test set.")

# %%
# create a Random Forest Classifier object with JUST 100-300 trees

# train the Random Forest

# make predictions (make sure not to use the same variable name as the one from your Decision Tree!)

# create a confusion matrix and print out the accuracy

# %% [markdown]
# Write here about:
#
#
# *   What accuracy did you get?
#
# *   What kind of predictions did your Random Forest make?
#
# *   How does the performance of your Random Forest model compare to the Decision Tree model?
#
#
# *   Why do you think that your Random Forest model performed differently than your Decision Tree model?

# %% [markdown]
# <h3> Task 3: Create a concept map of machine-learning </h3>
#
# Let's take a moment to review and reflect on what we know so far. This also helps the teaching team know where you stand and where we can help!
#
# Feel free to design and organize this concept map how you want, but just know that there's **no coding in this task**.
#
# Here's an example of what we're looking for:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You don't have to make yours look exactly like the example provided. Again, create it however you feel like is the best reflection of your current knowledge on machine-learning.
#
# The example is from this [site](https://vas3k.com/blog/machine_learning/?ref=hn) and we recommend checking it out as it does a very good job of explaining machine-learning simply.
